# %% [markdown]
# <a href="https://colab.research.google.com/github/huangjiaxun35-alt/TinySausage/blob/main/Training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yfinance as yf
import torch
import torch.nn as nn
import numpy as np
import pandas as pd
import sklearn

tickers = [
"AAPL","MSFT","NVDA","AMZN","GOOGL","GOOG","META","BRK-B","LLY","AVGO",
"TSLA","JPM","WMT","UNH","XOM","V","MA","JNJ","PG","HD",
"CVX","MRK","ABBV","PEP","KO","COST","ORCL","ADBE","CRM","ACN",
"CSCO","TMO","LIN","ABT","NFLX","AMD","DHR","WFC","DIS","TXN",
"PM","VZ","NEE","RTX","HON","IBM","AMGN","CAT","LOW","INTC",
"INTU","QCOM","GS","SBUX","BLK","SPGI","ISRG","NOW","GE","BKNG",
"MDT","AMAT","SYK","LMT","TJX","DE","ADP","PLD","CI","GILD",
"CB","MMC","DUK","SO","VRTX","USB","REGN","PGR","MO","TGT",
"AXP","ZTS","CME","PNC","UPS","NOC","ICE","CL","WM","ITW",
"NSC","FDX","AON","ECL","APD","SHW","EMR","GD","PSA","ROP",
"KMB","TRV","AZO","MCO","MSI","HUM","BSX","FIS","FISV","MAR",
"MET","AIG","PRU","ALL","AFL","PAYX","ROST","FAST","CTAS","PCAR",
"XEL","ED","ORLY","KR","YUM","IDXX","CMG","SYY","DRI","CAG",
"HSY","KHC","MKC","CLX","HRL","TSCO","WBA","DG","DLTR","BBY",
"EXC","PEG","EIX","FE","AEP","D","NEP","AWK","WEC","ES",
"ETR","NRG","CMS","PNW","DTE","AES","LNT","NI","EVRG","ATO",
"ARE","AVB","EQR","MAA","UDR","ESS","CPT","INVH","AMT","CCI",
"SBAC","DLR","EQIX","PSA","O","VTR","WELL","HST","RHP","WY",
"IP","PKG","WRK","BALL","SEE","CF","MOS","NEM","FCX","MLM",
"VMC","EXP","FANG","SLB","HAL","BKR","DVN","EOG","MPC","PSX",
"VLO","KMI","WMB","OKE","TRGP","ENPH","SEDG","NEE","DUK","SO",
"CSX","UNP","CPRT","ODFL","LUV","UAL","DAL","AAL","ALK","JBHT",
"CHRW","EXPD","UPS","FDX","URI","CAT","DE","PCAR","CMI","TT",
"ROK","ETN","PH","IR","XYL","IEX","AME","FTV","ITW","EMR",
"MMM","HON","GE","RTX","LMT","NOC","GD","TXT","HWM","BA",
"AXON","LHX","TDG","HEI","HII","BWXT","LDOS","NDSN","EFX","PAYC",
"ADSK","ANSS","CDNS","SNPS","INTU","WDAY","TEAM","CRM","NOW","ORCL",
"IBM","MSFT","GOOGL","META","ADBE","CSCO","ACN","TXN","QCOM","AVGO",
"AMD","NVDA","AMAT","LRCX","KLAC","MU","INTC","MCHP","ADI","NXPI",
"ON","MPWR","SWKS","QRVO","TER","ENTG","COHR","WOLF","GLW","APH",
"TEL","JCI","HUBB","ROST","TJX","MAR","HLT","BKNG","ABNB","EXPE",
"RCL","CCL","NCLH","MGM","WYNN","LVS","CZR","DKNG","PENN","CHDN",
"NFLX","DIS","PARA","WBD","FOXA","FOX","CMCSA","T","VZ","TMUS",
"EA","TTWO","ATVI","ROKU","SPOT","SONY","NTDOY","PYPL","SQ","MA",
"V","AXP","COF","DFS","SYF","JPM","BAC","WFC","C","GS",
"MS","BLK","SCHW","TROW","BEN","IVZ","NTRS","STT","BK","USB"
]
industries = [
"Information Technology","Information Technology","Information Technology","Consumer Discretionary","Communication Services","Communication Services","Communication Services","Financials","Health Care","Information Technology",
"Consumer Discretionary","Financials","Consumer Staples","Health Care","Energy","Financials","Financials","Health Care","Consumer Staples","Consumer Discretionary",
"Energy","Health Care","Health Care","Consumer Staples","Consumer Staples","Consumer Staples","Information Technology","Information Technology","Information Technology","Information Technology",
"Information Technology","Health Care","Materials","Health Care","Communication Services","Information Technology","Health Care","Financials","Communication Services","Information Technology",
"Consumer Staples","Communication Services","Utilities","Industrials","Industrials","Information Technology","Health Care","Industrials","Consumer Discretionary","Information Technology",
"Information Technology","Information Technology","Financials","Consumer Discretionary","Financials","Financials","Health Care","Information Technology","Industrials","Consumer Discretionary",
"Health Care","Information Technology","Health Care","Industrials","Consumer Discretionary","Industrials","Information Technology","Real Estate","Health Care","Health Care",
"Financials","Utilities","Utilities","Health Care","Financials","Health Care","Financials","Health Care","Financials","Consumer Staples",
"Financials","Health Care","Financials","Financials","Industrials","Industrials","Financials","Consumer Staples","Industrials","Industrials",
"Industrials","Financials","Materials","Materials","Industrials","Industrials","Financials","Real Estate","Information Technology","Information Technology",
"Real Estate","Industrials","Consumer Staples","Financials","Energy","Financials","Utilities","Financials","Consumer Staples","Financials",
"Financials","Financials","Financials","Financials","Financials","Information Technology","Consumer Discretionary","Industrials","Industrials","Industrials",
"Utilities","Utilities","Consumer Discretionary","Consumer Staples","Consumer Discretionary","Health Care","Consumer Discretionary","Consumer Staples","Consumer Discretionary","Consumer Staples",
"Consumer Staples","Consumer Staples","Consumer Staples","Consumer Staples","Consumer Staples","Consumer Staples","Consumer Staples","Consumer Discretionary","Consumer Discretionary","Consumer Discretionary",
"Utilities","Utilities","Utilities","Utilities","Utilities","Utilities","Utilities","Utilities","Utilities","Utilities",
"Real Estate","Real Estate","Real Estate","Real Estate","Real Estate","Real Estate","Real Estate","Real Estate","Real Estate","Real Estate",
"Materials","Materials","Materials","Materials","Materials","Materials","Materials","Materials","Materials","Materials",
"Materials","Materials","Energy","Energy","Energy","Energy","Energy","Energy","Energy","Energy",
"Energy","Energy","Energy","Energy","Energy","Utilities","Utilities","Utilities","Industrials","Industrials",
"Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials",
"Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials",
"Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials","Industrials",
"Information Technology","Information Technology","Information Technology","Information Technology","Information Technology","Information Technology","Information Technology","Information Technology","Information Technology","Information Technology",
"Information Technology","Information Technology","Information Technology","Information Technology","Information Technology","Information Technology","Information Technology","Information Technology","Information Technology","Information Technology",
"Information Technology","Information Technology","Information Technology","Information Technology","Information Technology","Information Technology","Information Technology","Information Technology","Information Technology","Information Technology",
"Information Technology","Information Technology","Information Technology","Information Technology","Information Technology","Information Technology","Information Technology","Information Technology","Information Technology","Information Technology",
"Consumer Discretionary","Consumer Discretionary","Consumer Discretionary","Consumer Discretionary","Consumer Discretionary","Consumer Discretionary","Consumer Discretionary","Consumer Discretionary","Consumer Discretionary","Consumer Discretionary",
"Communication Services","Communication Services","Communication Services","Communication Services","Communication Services","Communication Services","Communication Services","Communication Services","Communication Services","Communication Services",
"Communication Services","Communication Services","Communication Services","Communication Services","Communication Services","Communication Services","Communication Services","Financials","Financials","Financials",
"Financials","Financials","Financials","Financials","Financials","Financials","Financials","Financials","Financials","Financials"
]

#"Information Technology", 1
#"Health Care",            2
#"Financials",             3
#"Consumer Discretionary", 4
#"Consumer Staples",       5
#"Industrials",            6
#"Energy",                 7
#"Materials",              8
#"Utilities",              9
#"Real Estate",            10
#"Communication Services". 11



nIndus = []

for i in range (len(industries)):
  if industries[i] == "Information Technology":
    nIndus[i] = 1;
  if industries[i] == "Health Care":
    nIndus[i] = 2;
  if industries[i] == "Financials":
    nIndus[i] = 3;
  if industries[i] == "Consumer Discretionary":
    nIndus[i] = 4;
  if industries[i] == "Consumer Staples":
    nIndus[i] = 5;
  if industries[i] == "Industrials":
    nIndus[i] = 6;
  if industries[i] == "Energy":
    nIndus[i] = 7;
  if industries[i] == "Materials":
    nIndus[i] = 8;
  if industries[i] == "Utilities":
    nIndus[i] = 9;
  if industries[i] == "Real Estate":
    nIndus[i] = 10;
  if industries[i] == "Communication Services":
    nIndus[i] = 11;
  else:
    nIndus[i] = 0;


# first layer i just tickers, second is industries, third is the actual stock info

start = "2023-6-13"
end = "2026-03-09"


ts = torch.zeros(500, 1000, 10)
vsmcb = torch.zeros(500,10)

# for ts
for i in range(500):
  stock = yf.Ticker(tickers[i])
  hist = stock.history(start=start, end=end)
